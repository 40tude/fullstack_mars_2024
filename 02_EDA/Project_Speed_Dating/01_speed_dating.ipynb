# %% [markdown]
# #  Project Speed Dating

# %% [markdown]
# # Introduction
#
# ## Specifications
# * They are experiencing a **decrease** in the number of **matches**
# * They are trying to find a way to understand what makes people interested into each other.
# * Use the dataset to understand what makes people interested into each other to go on a **second date** together
#     * THe target is the column `dec` (index 95)
#
# ## Principle
# <p align="center">
# <img src="./assets/speed_dating.png" alt="drawing" width="600"/>
# <p>
#
# ## 360° questionnaire
# <p align="center">
# <img src="./assets/process.png" alt="drawing" width="800"/>
# <p>
#
# ## Data collection phases
# <p align="center">
# <img src="./assets/data_collection.png" alt="drawing" width="800"/>
# <p>
#
# * Time spent on the Word document : 4 + 4 + 1

# %%
# prelude
import pandas as pd
from pandas.io.formats.info import DataFrameInfo
import seaborn as sns
import matplotlib.pyplot as plt
import shutil
import os

kGold     = 1.618
kWidth    = 12
kHeight   = kWidth/kGold

# The dataset has many columns. 
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Make a copy of the dataset

# %%
dir = "/assets/"
name_in = "Speed_Dating_Data.csv"
name_out = "Speed_Dating_Data_Copy.csv"

current_dir = os.path.abspath("")
filename_in = current_dir + dir + name_in
filename_out = current_dir + dir + name_out

shutil.copyfile(filename_in, filename_out);

# %% [markdown]
# # Information about the form of the dataset

# %%
df = pd.read_csv(filename_out, encoding='unicode_escape')

# %%
df.shape

print(f"There are :")
print(f"\t{len(df.shape):>6_} dimensions")
print(f"\t{df.shape[0]:>6_} lines")
print(f"\t{df.shape[1]:>6_} columns")
# Out:
# There are :
# 	     2 dimensions
# 	 8_378 lines
# 	   195 columns

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %% [markdown]
# # Which type of data ?

# %%
count_types = df.dtypes.value_counts()
print(count_types)
# Out:
# float64    174
# int64       13
# object       8
# Name: count, dtype: int64

# %%
# df.info(verbose=True)

# %% [markdown]
# # Quick watch over the discrete/continuous data

# %%
df.describe(include="all")
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  \
# ...

# %% [markdown]
# ### Continuous variables
#   * 90% (174/195) of the columns are float
#   * many of the `attr_XXX` are float (pf_o_attr, attr1_1...)

# %% [markdown]
# # Empty cells analysis

# %%
print(f"Total # of cells = {df.shape[0]*df.shape[1]:>12_.2f}")

empty_cells = df.isna().sum().sum()
print(f"# of empty cells = {empty_cells:>12_.2f}")

percent_empty_cells = (100*df.isna().sum().sum()/(df.shape[0]*df.shape[1])).round(2)
print()
print(f"{percent_empty_cells:>.2f} % of the cells are empty")

df_tmp = pd.DataFrame(df.isna().sum().sort_values(ascending=False))
df_tmp = df_tmp.cumsum()

percent_80 = empty_cells*80/100
bob = df_tmp.loc[df_tmp[0]<=percent_80]
print()
print(f"80% of the empty cells ({percent_80:_.0f}) come from {len(bob)} features ({100*len(bob)/df.shape[1]:.2f} %, over {df.shape[1]})")
# Out:
# Total # of cells = 1_633_710.00
# # of empty cells =   432_016.00
#
# 26.44 % of the cells are empty
#
# 80% of the empty cells (345_613) come from 66 features (33.85 %, over 195)

# %% [markdown]
# ## % of empty cells per feature

# %%
pd.DataFrame((df.isna().sum() / len(df) * 100).sort_values(ascending=False).round(2)).head(20)
# Out:
#               0
# num_in_3  92.03
# numdat_3  82.14
# expnum    78.52
# sinc7_2   76.67
# amb7_2    76.67
# shar7_2   76.44
# attr7_2   76.32
# intel7_2  76.32
# fun7_2    76.32
# amb5_3    75.94
# attr7_3   75.94
# sinc7_3   75.94
# intel7_3  75.94
# fun7_3    75.94
# amb7_3    75.94
# shar7_3   75.94
# shar2_3   75.94
# attr5_3   75.94
# sinc5_3   75.94
# intel5_3  75.94

# %% [markdown]
# ## The spread of empty cells

# %%
plt.figure(figsize=(kWidth, kHeight))
plt.title("White=NAN, Black=Data")
_ = sns.heatmap(df.isna(), cbar=False)

# %% [markdown]
# <span style="color:yellow">some *blue* text</span>.
