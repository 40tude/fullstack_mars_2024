# %% [markdown]
# #  Uber OR North Face

# %% [markdown]
# * Voir
# * https://app.jedha.co/course/projects-unsupervised-machine-learning-ft/uber-pickups-ft
# * https://app.jedha.co/course/projects-unsupervised-machine-learning-ft/the-north-face-ecommerce-ft
